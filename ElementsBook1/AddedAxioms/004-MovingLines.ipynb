# %% [markdown]
# # Euclid Book 1, Additional Axiom 4
#
# A line [[Def I.2]](../Definitions/002-Line.ipynb) may be *moved* by moving its extremities [[Def I.3]](../Definitions/003-LineExtremities.ipynb) [[AddAxiom I.2]](002-MovingPoints.ipynb) and ensuring the line remains the same between them. A line that is not *moving* is said to be *fixed*.

# %%
using Euclid

# %% [markdown]
# ## 2D

# %%
#setup the chart space...
chart = euclid_chart(title="Euclid's Elements Book I, Added Axiom 1: Highlighting Points",
                     xlims=(-1,1), ylims=(-1,1.2))

# Describe and draw the line
euclid_legend(  chart,
                [line_legend(color=:steelblue), circle_legend(width=0f0), circle_legend(width=0f0)],
                [L"\text{A line may be \textit{moved} by moving its extremities}",
                    L"\text{  and ensuring the line remains the same between them.}",
                    L"\text{A line that is not \textit{moving} is said to be \textit{fixed}.}"])

A = line(Point2f(-0.25,-0.25), Point2f(0.25,0.25), color=:steelblue)
show_complete(A)

#Demonstrate a few moves
A_move_1 = move(A, Point2f(0,0))
A_move_2 = move(A, Point2f(-0.25,0), begin_at=Point2f(0.5,0.5), move_extremityA=false)
A_move_3 = move(A, Point2f(0.25,0.25), begin_at=Point2f(-0.25,0), move_extremityA=false)

# Draw the animation!
draw_animation(chart, "gifs/004-LineMove.gif") do t
    animate(A_move_1, 0.75f0π, 1.0f0π, t)
    animate(A_move_2, 1.16f0π, 1.25f0π, t)
    animate(A_move_3, 1.51f0π, 1.75f0π, t)
end
# Out:
# HTML{String}("<img src=\"data:image/gif;base64,...\" />")

# %% [markdown]
# ## 3D

# %%
#setup the chart space...
chart = euclid_chart3(title="Euclid's Elements Book I, Added Axiom 1: Highlighting Points",
                     xlims=(-1,1), ylims=(-1,1.2))

# Describe and draw the line
euclid_legend(  chart,
                [line_legend(color=:steelblue), circle_legend(width=0f0), circle_legend(width=0f0)],
                [L"\text{A line may be \textit{moved} by moving its extremities}",
                    L"\text{  and ensuring the line remains the same between them.}",
                    L"\text{A line that is not \textit{moving} is said to be \textit{fixed}.}"])

A = line(Point3f(-0.25,-0.25,-0.25), Point3f(0.25,0.25,0.25), color=:steelblue)
show_complete(A)

#Demonstrate a few moves
A_move_1 = move(A, Point3f(0))
A_move_2 = move(A, Point3f(-0.25,0,-0.25), begin_at=Point3f(0.5,0.5,0.5), move_extremityA=false)
A_move_3 = move(A, Point3f(0.25,0.25,0.25), begin_at=Point3f(-0.25,0,-0.25), move_extremityA=false)

# Draw the animation!
draw_animation(chart, "gifs/004-LineMove-3D.gif") do t
    animate(A_move_1, 0.75f0π, 1.0f0π, t)
    animate(A_move_2, 1.16f0π, 1.25f0π, t)
    animate(A_move_3, 1.51f0π, 1.75f0π, t)
end
# Out:
# HTML{String}("<img src=\"data:image/gif;base64,...\" />")
