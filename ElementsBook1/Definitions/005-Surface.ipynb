# %% [markdown]
# # Euclid Book 1, Definition 5
#
# A *surface* is that which has length and breadth only.

# %%
include("../../Euclid.jl");

# %%
#setup the chart space...
set_theme!(theme_dark())
f = Figure()
ax = euclid_axis(f[1,1], title="Euclid's Elements Book I, Definition 5: Surface")
xlims!(ax, -1,1)
ylims!(ax, -1,1)


# Describe and draw the surface
axislegend(ax,
           [square_legend(color=:steelblue)],
           [L"\text{A \textit{surface} is that which has length and breadth only.}"])

A = just_surface([Point2f0(-0.5, -0.5), Point2f0(0.5, -0.5), Point2f0(0.5, 0.5), Point2f0(-0.5, 0.5)],
                 color=:steelblue)

# Draw the animation!
framerate = 24
d_s = 24
t_rots = 2π
timestamps = range(0,t_rots, step=t_rots/(d_s*framerate))

display_gif(record(f, "gifs/005-Surface.gif", timestamps; framerate=framerate) do t

    # Show and hide the surface
    animate(A, 0.5f0π, 1f0π, t, fade_start=1.25f0π, fade_end=1.75f0π)
end)
# Out:
# HTML{String}("<img src=\"data:image/gif;base64,...\" />")
