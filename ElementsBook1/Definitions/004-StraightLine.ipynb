# %% [markdown]
# # Euclid Book 1, Definition 4
#
# A *straight line* is a line [[Def I.2]](002-Line.ipynb) which lies evenly with the points [[Def I.1]](001-Point.ipynb) on itself.

# %%
using Euclid

# %%
#setup the chart space...
chart = euclid_chart(title="Euclid's Elements Book I, Definition 4: Straight Line",
                     xlims=(-1,1), ylims=(-1,1))

# Describe and draw the line
euclid_legend(  chart,
                [line_legend(color=:steelblue), line_legend(linestyle=:dot, color=:pink)],
                [L"\text{A \textit{straight line} is a line which lies evenly with}",
                    L"\text{the points on itself.}"])

A = line(Point2f(-0.25,-0.25), Point2f(0.25,0.25), color=:steelblue)
show_complete(A)

# Highlight that it's a straight line
A_straight = highlight_straight(A, 5, color=:pink)

# Draw the animation!
draw_animation(chart, "gifs/004-StraightLine.gif") do t
    animate(A_straight, 0f0π, 2f0π, t)
end
# Out:
# HTML{String}("<img src=\"data:image/gif;base64,...\" />")

# %%
#setup the chart space...
chart = euclid_chart3(title="Euclid's Elements Book I, Definition 4: Straight Line",
                      xlims=(-1,1), ylims=(-1,1))

# Describe and draw the line
euclid_legend(  chart,
                [line_legend(color=:steelblue), line_legend(linestyle=:dot, color=:pink)],
                [L"\text{A \textit{straight line} is a line which lies evenly with}",
                    L"\text{the points on itself.}"])

A = line(Point3f(-0.25,-0.25,-0.25), Point3f(0.25,0.25,0.25), color=:steelblue)
show_complete(A)

# Highlight that it's a straight line
A_straight = highlight_straight(A, 5, color=:pink, width=0.02f0)

# Draw the animation!
draw_animation(chart, "gifs/004-StraightLine-3D.gif") do t
    animate(A_straight, 0f0π, 2f0π, t)
end
# Out:
# HTML{String}("<img src=\"data:image/gif;base64,...\" />")
